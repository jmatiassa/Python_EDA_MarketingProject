# %%
#importaciones de datos
import pandas as pd

#importación de src codigo de soporte con las funciones necesarias para la limpieza
import sys
sys.path.append("..")
from src import sp_eda_limpieza as sp

# %%
#ajustes de visualización
pd.set_option('display.max_columns', None)

# %%
#lectura de los ficheros de datos
df_bankadditional_raw=pd.read_csv(r'C:\Users\matis\Desktop\EDA_MARKETING\data\fuentes de datos\bank-additional.csv')

# %%
sheets=pd.read_excel(r'C:\Users\matis\Desktop\EDA_MARKETING\data\fuentes de datos\customer-details.xlsx',sheet_name=None)
df_customerdetails_raw=pd.concat(sheets.values(),ignore_index=True)

# %%
#se cran las variables que almacenan la copia del fichero original. estas se manipularán para ser limpiadas
df_bankadditional=df_bankadditional_raw.copy()
df_customerdetails=df_customerdetails_raw.copy()

# %%
#Eda preeliminar del fichero customer details
sp.eda_preliminar(df_customerdetails)
# Out:
#        Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 18441  108057        2         1  2012-10-09                  7
# 30016   20759        1         1  2014-01-03                 22
# 10680  108224        0         2  2012-06-03                 11
# 36018  108272        0         2  2014-12-07                 32
# 39008   47511        1         0  2014-12-03                 10
#
#                                          ID
# 18441  8a81370d-ff25-4b2d-80f9-6e497a9ff178
# 30016  4afc7d59-aff1-4223-9286-7cfaaccababd
# 10680  7a14695c-f993-411a-b2bc-9a13366498fd
# 36018  60081fae-4ff4-4e46-afe0-c5a3e03ebfcc
# 39008  d5e3114b-3a3a-4f28-bec9-f2fc628209a6
# --------------------
# INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43170 entries, 0 to 43169
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Income             43170 non-null  int64
# ...

# %% [markdown]
# ## Análisis
# - Borrar columna unnamed:0
# - nulos 0
# - duplicados 0
# - categorías: todo ok
# ## To do
# - Borrar columa unnamed:0

# %%
sp.borrar_unnamed(df_customerdetails)
# Out:
# Columnas originales: Index(['Income', 'Kidhome', 'Teenhome', 'Dt_Customer', 'NumWebVisitsMonth',
#        'ID'],
#       dtype='object')
# La columna 'Unnamed: 0' no se encuentra en el DataFrame
#        Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 25143  170312        0         1  2013-03-15                  6
#
#                                          ID
# 25143  1b070063-621d-4093-8275-21f6b30890f8

# %%
#Eda preeliminar del fichero bankadditional
sp.eda_preliminar(df_bankadditional)
# Out:
#        Unnamed: 0   age           job   marital            education  default  \
# 40899       41066   NaN    technician   MARRIED    university.degree      0.0
# 21689       21786   NaN        admin.    SINGLE    university.degree      0.0
# 19046       19143  44.0    technician  DIVORCED    university.degree      NaN
# 19248       19345  51.0  entrepreneur   MARRIED             basic.9y      0.0
# 22783       22880  32.0    technician   MARRIED  professional.course      0.0
#
#        housing  loan   contact  duration  campaign  pdays  previous  \
# 40899      0.0   0.0  cellular       119         1    999         3
# 21689      0.0   0.0  cellular       162         1    999         0
# 19046      0.0   0.0  cellular       117         1    999         0
# 19248      0.0   0.0  cellular       135         1    999         0
# 22783      1.0   1.0  cellular        69         2    999         0
#
#           poutcome  emp.var.rate cons.price.idx cons.conf.idx euribor3m  \
# ...

# %% [markdown]
# ## Análisis to do
# - Borrar columna unnamed
# - Poner iniciales de las columnas en minúsculas
# - conversión de booleanos a sí no: default,housing,loan
# - conversión de valores a int: nr.employed
# - conversión de valores float: cons.price.idx,cons.conf.ids, euribor3m
# - eliminar pdays: el 75% de lso valores son 999
# - pasar  a fecha la columna date
# - pasar valores a minúsculas: marital, poutcome
# - education, cambiar el punto por una _
# - cambiar - por _ en job
# - cambiar Id_ por ID
# - Cambiar Y por Subscribed
# - Unir los dos dataframes
# - gestión de nulos
# - conversión de coordenadas a ciudad, región, país

# %%
#borrar la columna unnamed
sp.borrar_unnamed(df_bankadditional)
# Out:
# Columnas originales: Index(['Unnamed: 0', 'age', 'job', 'marital', 'education', 'default',
#        'housing', 'loan', 'contact', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'date', 'latitude',
#        'longitude', 'id_'],
#       dtype='object')
# Columna 'Unnamed: 0' eliminada
#         age     job  marital          education  default  housing  loan  \
# 20725  35.0  admin.  MARRIED  university.degree      NaN      0.0   0.0
#
#         contact  duration  campaign  pdays  previous     poutcome  \
# 20725  cellular       181         5    999         0  NONEXISTENT
#
#        emp.var.rate cons.price.idx cons.conf.idx euribor3m nr.employed   y  \
# 20725           1.4         93,444         -36,1     4,965      5228,1  no
#
#                  date  latitude  longitude  \
# 20725  20-agosto-2016    30.625    -97.301
#
#                                         id_
# ...

# %%
#pasar columnas a mayúscula
sp.columnas_mayuscula(df_bankadditional)
# Out:
# Columnas pasadas a mayúscualas
#         Age          Job  Marital Education  Default  Housing  Loan   Contact  \
# 25903  36.0  blue-collar  MARRIED  basic.6y      0.0      0.0   0.0  cellular
#
#        Duration  Campaign  Pdays  Previous     Poutcome  Emp.var.rate  \
# 25903       299         2    999         0  NONEXISTENT          -0.1
#
#       Cons.price.idx Cons.conf.idx Euribor3m Nr.employed   Y            Date  \
# 25903           93,2           -42      4,12      5195,8  no  9-octubre-2015
#
#        Latitude  Longitude                                   Id_
# 25903    31.634   -107.287  55b2d0d1-c5bb-41b6-ba2c-00057a35c2c2

# %%
#transformar valores 1 / 0 a yes, no
sp.transformar_booleanos(df_bankadditional)
# Out:
# Columnas booleanas detectadas: ['Default', 'Housing', 'Loan']
#
# Muestra del DataFrame:
#         Age         Job   Marital            Education Default Housing Loan  \
# 11431  50.0    services  DIVORCED                  NaN      no      no   no
# 1150   50.0  technician   MARRIED  professional.course      no      no   no
# 16300  23.0      admin.    SINGLE  professional.course      no      no   no
# 24472  31.0  technician    SINGLE    university.degree      no     yes  yes
# 6438   51.0      admin.  DIVORCED    university.degree      no     yes   no
#
#          Contact  Duration  Campaign  Pdays  Previous     Poutcome  \
# 11431  telephone       250         3    999         0  NONEXISTENT
# 1150   telephone       103         3    999         0  NONEXISTENT
# 16300   cellular       187         1    999         0  NONEXISTENT
# 24472   cellular       118         2    999         0  NONEXISTENT
# 6438   telephone        72        18    999         0  NONEXISTENT
#
# ...

# %%
#cambiar , por . y convertir a float
sp.convertir_a_float(df_bankadditional)
# Out:
# Se han modificado las siguientes columnas:['Cons.price.idx', 'Cons.conf.idx', 'Euribor3m', 'Nr.employed']
#         Age          Job Marital Education Default Housing Loan   Contact  \
# 13967  26.0  blue-collar  SINGLE  basic.9y     NaN     yes   no  cellular
#
#        Duration  Campaign  Pdays  Previous     Poutcome  Emp.var.rate  \
# 13967       151         2    999         0  NONEXISTENT           1.4
#
#        Cons.price.idx  Cons.conf.idx  Euribor3m  Nr.employed   Y  \
# 13967          93.918          -42.7      4.963       5228.1  no
#
#                     Date  Latitude  Longitude  \
# 13967  12-diciembre-2017    35.306   -101.423
#
#                                         Id_
# 13967  688c247b-b6d8-4444-a018-da4ca9e9f073

# %%
#redondear decimal y convertir a int
sp.float_a_int(df_bankadditional,'Nr.employed')
# Out:
# La columna Nr.employed ha sido cambiada a numero entero y redondeada
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             37880 non-null  float64
#  1   Job             42655 non-null  object
#  2   Marital         42915 non-null  object
#  3   Education       41193 non-null  object
#  4   Default         34019 non-null  object
#  5   Housing         41974 non-null  object
#  6   Loan            41974 non-null  object
#  7   Contact         43000 non-null  object
#  8   Duration        43000 non-null  int64
#  9   Campaign        43000 non-null  int64
#  10  Pdays           43000 non-null  int64
#  11  Previous        43000 non-null  int64
#  12  Poutcome        43000 non-null  object
#  13  Emp.var.rate    43000 non-null  float64
#  14  Cons.price.idx  42529 non-null  float64
# ...

# %%
sp.eliminar_columna(df_bankadditional,'Pdays')
# Out:
# Se ha eliminado la columna Pdays
#        Age         Job   Marital            Education Default Housing Loan  \
# 2792  32.0  technician  DIVORCED  professional.course      no     yes   no
#
#         Contact  Duration  Campaign  Previous     Poutcome  Emp.var.rate  \
# 2792  telephone        70         2         0  NONEXISTENT           1.1
#
#       Cons.price.idx  Cons.conf.idx  Euribor3m  Nr.employed   Y  \
# 2792          93.994          -36.4      4.859         5191  no
#
#                  Date  Latitude  Longitude  \
# 2792  27-febrero-2018    40.225    -89.901
#
#                                        Id_
# 2792  d7783d5b-528f-4a05-b93a-84fb4af29e8f

# %%
#convertir la columna a fecha
sp.convertir_fecha(df_bankadditional,'Date','mixed')
# Out:
# Se ha convertido la columna Date a fecha
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             37880 non-null  float64
#  1   Job             42655 non-null  object
#  2   Marital         42915 non-null  object
#  3   Education       41193 non-null  object
#  4   Default         34019 non-null  object
#  5   Housing         41974 non-null  object
#  6   Loan            41974 non-null  object
#  7   Contact         43000 non-null  object
#  8   Duration        43000 non-null  int64
#  9   Campaign        43000 non-null  int64
#  10  Previous        43000 non-null  int64
#  11  Poutcome        43000 non-null  object
#  12  Emp.var.rate    43000 non-null  float64
#  13  Cons.price.idx  42529 non-null  float64
#  14  Cons.conf.idx   43000 non-null  float64
#  15  Euribor3m       33744 non-null  float64
# ...

# %%
#Convertir marital a minúsculas
sp.convertir_minusculas(df_bankadditional,'Marital')
# Out:
#        Age         Job Marital          Education Default Housing Loan  \
# 22404  NaN  technician  single  university.degree      no     yes   no
#
#         Contact  Duration  Campaign  Previous     Poutcome  Emp.var.rate  \
# 22404  cellular        55         3         0  NONEXISTENT           1.4
#
#        Cons.price.idx  Cons.conf.idx  Euribor3m  Nr.employed   Y       Date  \
# 22404          93.444          -36.1        NaN         5228  no 2019-12-05
#
#        Latitude  Longitude                                   Id_
# 22404    31.353   -107.896  50767884-a869-4c84-aa18-d5f9f52b3346

# %%
#convertir valores a minúsculas en la columna poutcome
sp.convertir_minusculas(df_bankadditional,'Poutcome')
# Out:
#         Age      Job Marital    Education Default Housing Loan   Contact  \
# 40186  21.0  student  single  high.school      no     yes   no  cellular
#
#        Duration  Campaign  Previous Poutcome  Emp.var.rate  Cons.price.idx  \
# 40186       326         2         1  failure          -1.7          94.027
#
#        Cons.conf.idx  Euribor3m  Nr.employed   Y       Date  Latitude  \
# 40186          -38.3      0.899         4992  no 2019-03-25     34.16
#
#        Longitude                                   Id_
# 40186   -117.401  851c79b4-d0db-4b3f-9fb4-0384e4541ebc

# %%
#CAMBIAR . POR _
sp.punto_barrabaja(df_bankadditional,'Education')
# Out:
# Se ha cambiado '.' por '_' en la columna Education
#         Age          Job  Marital Education Default Housing Loan    Contact  \
# 10187  32.0  blue-collar  married  basic_9y      no     yes  yes  telephone
#
#        Duration  Campaign  Previous     Poutcome  Emp.var.rate  \
# 10187       452         1         0  nonexistent           1.4
#
#        Cons.price.idx  Cons.conf.idx  Euribor3m  Nr.employed   Y       Date  \
# 10187          94.465          -41.8       4.96         5228  no 2015-12-06
#
#        Latitude  Longitude                                   Id_
# 10187    39.922    -70.529  a1ba00e4-ccae-4e63-9ddf-7485c5e14e92

# %%
#Cambiar - por _
sp.guion_barrabaja(df_bankadditional,'Job')
# Out:
# Se ha cambiado '-' por '_' en la columna Job
# Job
# admin.           10873
# blue_collar       9654
# technician        7026
# services          4162
# management        3050
# retired           1790
# entrepreneur      1522
# self_employed     1489
# housemaid         1123
# unemployed        1063
# student            903
# nan                345
# Name: count, dtype: int64

# %%
#Cambiar el nombre de la columna Id_ por ID
sp.cambiar_columna(df_bankadditional,'Id_','ID')
# Out:
# Se ha cambiado el nombre de la columna Id_ por ID
#       Age     Job  Marital    Education Default Housing Loan    Contact  \
# 664  38.0  admin.  married  high_school      no      no   no  telephone
#
#      Duration  Campaign  Previous     Poutcome  Emp.var.rate  Cons.price.idx  \
# 664       112         4         0  nonexistent           1.1          93.994
#
#      Cons.conf.idx  Euribor3m  Nr.employed   Y       Date  Latitude  \
# 664          -36.4      4.857         5191  no 2017-06-11    45.852
#
#      Longitude                                    ID
# 664      -68.6  0f35f798-26b8-4da4-a056-92b8eb0d9a22

# %%
#Cambiar el nombre de la columna Y por Subscribed
sp.cambiar_columna(df_bankadditional,'Y','Subscribed')
# Out:
# Se ha cambiado el nombre de la columna Y por Subscribed
#         Age     Job   Marital          Education Default Housing Loan  \
# 19166  40.0  admin.  divorced  university_degree      no     yes  yes
#
#         Contact  Duration  Campaign  Previous     Poutcome  Emp.var.rate  \
# 19166  cellular        65         1         0  nonexistent           1.4
#
#        Cons.price.idx  Cons.conf.idx  Euribor3m  Nr.employed Subscribed  \
# 19166          93.444          -36.1        NaN         5228         no
#
#             Date  Latitude  Longitude                                    ID
# 19166 2015-04-27    32.481    -80.556  3686a147-c765-43ae-a210-650f40085903

# %%
df_bankadditional.columns
# Out:
# Index(['Age', 'Job', 'Marital', 'Education', 'Default', 'Housing', 'Loan',
#        'Contact', 'Duration', 'Campaign', 'Previous', 'Poutcome',
#        'Emp.var.rate', 'Cons.price.idx', 'Cons.conf.idx', 'Euribor3m',
#        'Nr.employed', 'Subscribed', 'Date', 'Latitude', 'Longitude', 'ID'],
#       dtype='object')

# %% [markdown]
# Se unen los dos dataframes, df_bank_limpio y df_customerdetails

# %%
df_bank_merge=df_bankadditional.merge(df_customerdetails,how='outer',on='ID' )

# %%
sp.eda_preliminar(df_bank_merge)
# Out:
#         Age         Job   Marital          Education Default Housing Loan  \
# 36101   NaN    services  divorced        high_school      no      no  yes
# 27015   NaN    services  divorced  university_degree      no     yes   no
# 33534  56.0  management  divorced           basic_9y     NaN     yes   no
# 25440  36.0      admin.    single  university_degree      no     yes   no
# 8310    NaN   housemaid   married           basic_4y     NaN     yes   no
#
#          Contact  Duration  Campaign  Previous     Poutcome  Emp.var.rate  \
# 36101  telephone     176.0       2.0       0.0  nonexistent           1.1
# 27015   cellular     335.0       1.0       1.0      failure          -1.8
# 33534  telephone     313.0       2.0       0.0  nonexistent           1.1
# 25440   cellular    1217.0       2.0       0.0  nonexistent           1.4
# 8310    cellular     195.0       1.0       0.0  nonexistent           1.4
#
#        Cons.price.idx  Cons.conf.idx  Euribor3m  Nr.employed Subscribed  \
# ...

# %%
df_bank_merge.to_csv('bank_merge.csv')
